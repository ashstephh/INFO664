# %% [markdown]
# ## HW #3
# **Name: Ashley Hernandez   Date: 9/17/2026**

# %% [markdown]
# (week-long raw data)
# **Date Type of Commute Commute Time Steps**
#
# Sept 1st Bus: 59 mins, 16,770 steps - Fitness App, Train: 63 mins
#
# Sep 2nd Train: 52 mins, 10,401 steps - Fitness App, Train: 12 mins, Train: 65 mins
#
# Sep 3rd Bus: 30 mins, 11,992 steps - Fitness App, Train: 48 mins, Train: 55 mins
#
# Sep 4th Train: 62 mins, 17,433 steps - Fitness App, Train: 58 mins
#
# Sep 5th Car: 45 mins, 14,603 steps - Fitness App, Train: 80 mins, Bus: 75 mins, Uber: 40 mins,
#
# Sep 6th Walk: 15 mins, 5,796 steps - Fitness App
#
# Sep 7th 0 mins, 3,596 steps - Fitness App
#
# Sep 8th Train: 48 mins, 6,332 steps - Fitness App, Train: 58 mins

# %%
#Dataset turned into a dictionary. Utilizing keyword pairs such as date and step_count to assign data points.
commute_fitness = [
    {
       "date": "Sep 1st",
        "bus_commute": "59:00",
        "train_commute": "63:00",
        "car_commute": "0:00",
        "walk_commute": "0.00",
        "step_count": "16700",
    },
    {
         "date": "Sep 2nd",
        "bus_commute": "0:00",
        "train_commute": ["52:00", "12:00", "65:00"],
        "car_commute": "0:00",
        "walk_commute": "0.00",
        "step_count": "10401",
    },
    {
        "date": "Sep 3rd",
        "bus_commute": "30:00",
        "train_commute": ["48:00", "55:00"],
        "car_commute": "0:00",
        "walk_commute": "0.00",
        "step_count": "11992",
    },
    {
         "date": "Sep 4th",
        "bus_commute": "0:00",
        "train_commute": ["62:00", "58:00"],
        "car_commute": "0:00",
        "walk_commute": "0.00",
        "step_count": "17433",
    },
    {
        "date": "Sep 5Th",
        "bus_commute": "75:00",
        "train_commute": "80:00",
        "car_commute": "85:00",
        "walk_commute": "0.00",
        "step_count": "14603",
    },
    {
        "date": "Sep 6th",
        "bus_commute": "0:00",
        "train_commute": "0:00",
        "car_commute": "0:00",
        "walk_commute": "15:00",
        "step_count": "5796",
    },
    {
        "date": "Sep 7th",
        "bus_commute": "0:00",
        "train_commute": "0:00",
        "car_commute": "0:00",
        "walk_commute": "0.00",
        "step_count": "3596",
    },
    {
        "date": "Sep 8th",
        "bus_commute": "0:00",
        "train_commute": ["48:00", "58:00"],
        "car_commute": "0:00",
        "walk_commute": "0.00",
        "step_count": "6332",
   },
]
print(commute_fitness) #printed dictionary
# Out:
# [{'date': 'Sep 1st', 'bus_commute': '59:00', 'train_commute': '63:00', 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '16700'}, {'date': 'Sep 2nd', 'bus_commute': '0:00', 'train_commute': ['52:00', '12:00', '65:00'], 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '10401'}, {'date': 'Sep 3rd', 'bus_commute': '30:00', 'train_commute': ['48:00', '55:00'], 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '11992'}, {'date': 'Sep 4th', 'bus_commute': '0:00', 'train_commute': ['62:00', '58:00'], 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '17433'}, {'date': 'Sep 5Th', 'bus_commute': '75:00', 'train_commute': '80:00', 'car_commute': '85:00', 'walk_commute': '0.00', 'step_count': '14603'}, {'date': 'Sep 6th', 'bus_commute': '0:00', 'train_commute': '0:00', 'car_commute': '0:00', 'walk_commute': '15:00', 'step_count': '5796'}, {'date': 'Sep 7th', 'bus_commute': '0:00', 'train_commute': '0:00', 'car_commute': '0:00', 'walk_commute': '0.00
# ...

# %%
sorted_step_fitness = sorted(commute_fitness, key=lambda step: int(step['step_count'])) #sorting dictionary by step_count.Implemented int() in the function to make the sorting more accurate
print(sorted_step_fitness)

sorted_bus_commute = sorted(commute_fitness, key=lambda bus:bus["bus_commute"], reverse = True) #sorting dictionary by bus_commute. Implemented the reverse function to go from largest to smallest
print(sorted_bus_commute)
# Out:
# [{'date': 'Sep 7th', 'bus_commute': '0:00', 'train_commute': '0:00', 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '3596'}, {'date': 'Sep 6th', 'bus_commute': '0:00', 'train_commute': '0:00', 'car_commute': '0:00', 'walk_commute': '15:00', 'step_count': '5796'}, {'date': 'Sep 8th', 'bus_commute': '0:00', 'train_commute': ['48:00', '58:00'], 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '6332'}, {'date': 'Sep 2nd', 'bus_commute': '0:00', 'train_commute': ['52:00', '12:00', '65:00'], 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '10401'}, {'date': 'Sep 3rd', 'bus_commute': '30:00', 'train_commute': ['48:00', '55:00'], 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '11992'}, {'date': 'Sep 5Th', 'bus_commute': '75:00', 'train_commute': '80:00', 'car_commute': '85:00', 'walk_commute': '0.00', 'step_count': '14603'}, {'date': 'Sep 1st', 'bus_commute': '59:00', 'train_commute': '63:00', 'car_commute': '0:00', 'walk_commute': '0.00',
# ...

# %%
commute_fitness.append({ #added a new key to the dictionary utilizing the append function
    "date": "Sept 16th",
    "bus_commute": "60:00",
    "train_commute": ["12:00", "10:00","58:00"],
    "car_commute": "0:00",
    "walk_commute": "35:00",
    "step_count": "12,341"
})

print(commute_fitness)
# Out:
# [{'date': 'Sep 1st', 'bus_commute': '59:00', 'train_commute': '63:00', 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '16700'}, {'date': 'Sep 2nd', 'bus_commute': '0:00', 'train_commute': ['52:00', '12:00', '65:00'], 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '10401'}, {'date': 'Sep 3rd', 'bus_commute': '30:00', 'train_commute': ['48:00', '55:00'], 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '11992'}, {'date': 'Sep 4th', 'bus_commute': '0:00', 'train_commute': ['62:00', '58:00'], 'car_commute': '0:00', 'walk_commute': '0.00', 'step_count': '17433'}, {'date': 'Sep 5Th', 'bus_commute': '75:00', 'train_commute': '80:00', 'car_commute': '85:00', 'walk_commute': '0.00', 'step_count': '14603'}, {'date': 'Sep 6th', 'bus_commute': '0:00', 'train_commute': '0:00', 'car_commute': '0:00', 'walk_commute': '15:00', 'step_count': '5796'}, {'date': 'Sep 7th', 'bus_commute': '0:00', 'train_commute': '0:00', 'car_commute': '0:00', 'walk_commute': '0.00
# ...
