# %% [markdown]
# # Week 2 - HW
# **Name: Ashley Hernandez**
# -

# %% [markdown]
# Four years after crashing onto our screens with unforgettable lines like, "I don't want to be an individual on my own," Derry Girls wrapped up its third and final series in 2022.
#
# This Channel 4 TV sitcom became an unexpected global sensation after hitting Netflix (and even made it onto The Simpsons with their Dairy Girls ice-cream parlour, because why not?). It’s a riotous, award-winning comedy that never fails to make you laugh, cringe, and cry (usually in that order).
#
# Written by Derry’s very own Lisa McGee and starring an all-star cast from the city, the show is set in 1990s Derry, where four teenage girls and one "wee English fella" try to survive their awkward teen years against the backdrop of The Troubles.
#
# Derry gets a starring role too, with its historic 400-year-old city walls, the famous Bogside area, The Guildhall, and its iconic churches all making an appearance. While a lot has changed in Derry since the '90s, the one thing that hasn’t is the humour—and the warm welcome you get when you visit. So, why not come and see the place that inspired this hilarious and heartwarming show?

# %%
tv_show = "Derry Girls"
creator = "Lisa McGee"
years = "1990s"
city = "Derry"
famous_place = "The Guildhall"

derry_girls = f'The show {tv_show} was created by {creator} which follows a group of teenagers in the {years} during the Troubles. It takes place in {city} which is home to the {famous_place}.'
print(derry_girls)
# Out:
# The show Derry Girls was created by Lisa McGee which follows a group of teenagers in the 1990s during the Troubles. It takes place in Derry which is home to the The Guildhall.

# %% [markdown]
# https://www.visitderry.com/derry-girls

# %%
fall_recipes = """Share on facebook
Share on pinterest
Share by email
Print recipe
When the weather starts to turn chilly, it’s a sign to turn on the oven (finally!) and bake up something delicious using the season’s bounty. Apples, pumpkin, and pears are some of our favorite fall ingredients to work with—especially when they’re enhanced with pantry staples like warm spices and maple syrup—but other picks like bananas and cranberries are just as versatile and cozy. Before holiday cookies take center stage, hunker down with these autumnal treats that are perfect for breakfast, an afternoon pick-me-up, dessert, and everything in between. You’ll find muffins, quick breads, jammy pies, and dinner party-ready cakes, including some one-bowl recipes when you need something sweet and simple with minimal effort. With so many crave-worthy options, you’re bound to fall for them all!    

Chocolate-Swirled Pumpkin Muffins   


These two-toned treats couldn’t be easier to make: Simply stir cocoa powder into some of the pumpkin mixture to make a chocolate batter, then layer and swirl the two flavors for the best of both worlds. Make these chocolatey pumpkin muffins in advance and enjoy them all week long, or pop them in the freezer for an on-the-go breakfast or treat.   

Get the recipe: Chocolate-Swirled Pumpkin Muffins   

Salted Maple Chai Pull-Apart Bread   


In this brunch-worthy recipe, a brown sugar and maple filling is amped up with cinnamon, cardamom, and ginger, which infuses each bite with peak fall coziness. Arranging the folded dough pieces in a loaf pan accordion-style makes assembly easy and creates layers of sweet, pillowy bread that’s hard to stop snacking on.    

This fragrant, earthy loaf bread comes together in an hour and uses gluten-free flour for an allergy-friendly treat. The creamy glaze adds just the right amount of sweetness to each hearty slice of the fall-favorite flavor.    

Get the recipe: The Gluten-Free Pumpkin Bread 

Baked Apple Cider Donuts   


A warm, sugar-coated cider donut is a hallmark of fall outings—now you can bring the orchard experience to your own kitchen. These baked donuts are made with reduced cider for maximum apple flavor and dusted with spiced sugar for the perfect finishing touch.   

Get the recipe: Baked Apple Cider Donuts 

Pear Upside-Down Cake   


Give pears—another seasonal star—some love with this delicious fall dessert. Slices of pear caramelize with butter and brown sugar while the cake bakes, then transform into a sweet, tender topping when you flip it over for the great reveal.      

Get the recipe: Pear Upside-Down Cake 

Cranberry Bars   


This large-format treat works as well for a potluck dessert as it does for a soccer team snack. A tangy cream cheese dough does double duty as both the crust and the topping, and canned cranberry sauce makes for the easiest filling."""   

apple_count = fall_recipes.count("apple");
pumpkin_count = fall_recipes.count("pumpkin");
print(f'Frequency count of apple: {apple_count}');  
print(f'Frequency count of pumpkin: {pumpkin_count}'); 

pie_count = fall_recipes.count("pie");
muffins_count = fall_recipes.count("muffins");

print(f'Frequency count of pie: {pie_count}'); 
print(f'Frequency count of muffins: {muffins_count}'); 

#https://www.savoryonline.com/articles/fall-baking-recipes/
# Out:
# Frequency count of apple: 8
# Frequency count of pumpkin: 7
# Frequency count of pie: 7
# Frequency count of muffins: 3

# %% [markdown]
# **Dear Data**

# %% [markdown]
# Tracking music/audiobook alongside commute time/type of commute

# %% [markdown]
# **Sept 1st**
# 59 mins - Bus
# 63 mins - Train
# 16,770 steps - Fitness App
# 42 songs - Spotify
#
# **Sep 2nd**
# 52 mins - Train
# 12 mins - Train
# 65 mins - Train
# 10,401 steps - Fitness App
# 83 songs - Spotify
# 42 mins audiobook - Libby
# **Sep 3rd**
# 30 mins - Bus
# 48 mins - Train
# 55 mins - Train
# 11,992 steps - Fitness App
# 108 songs - Spotify
#
# **Sep 4th**
# 62 mins - Train
# 58 mins - Train
# 17,433 steps - Fitness App
# 42 songs - Spotify
# 60 mins audiobook - Libby
#
# **Sep 5th**
# 45 mins - Car
# 80 mins - Train
# 75 mins - Bus
# 40 mins - Uber
# 14,603 steps - Fitness App
# 96 songs - Spotify
#
# **Sep 6th**
# 15 mins - Walk
# 5,796 steps - Fitness App
# 1 song - Spotify
#
# **Sep 7th**
# 0 mins
# 3,596 steps - Fitness App
# 1 song - Spotify
#
# **Sep 8th**
# 48 mins - Train
# 58 mins - Train
# 6,332 steps - Fitness App
# 0 song
