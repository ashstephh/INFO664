# %% [markdown]
# ## HW 4
# **Name: Ashley Hernandez**

# %%
#for loops

numbers_list = [1, 4, 6, 8, 3]
for i in numbers_list:
    print(f'The square of {i} is {i*i}')
# Out:
# The square of 1 is 1
# The square of 4 is 16
# The square of 6 is 36
# The square of 8 is 64
# The square of 3 is 9

# %%
for num in numbers_list:
    if (num % 2 == 0):
        print(f'{num} is even')
    else:
        print(f'{num} is odd')
# Out:
# 1 is odd
# 4 is even
# 6 is even
# 8 is even
# 3 is odd

# %%
import csv
with open("moma_artists.csv", "r", encoding = "utf-8") as file:
    reader = csv.DictReader(file)
    data = list(reader)


artists_with_gender_data = []
male_artists = []
female_artists = []
non_binary_artists = []

for artist in data:
    if artist["Gender"] == "female":
        female_artists = []
        female_artists.append(artist)
        artists_with_gender_data.append(artist)
    elif artist["Gender"] == "male":
        male_artists = []
        male_artists.append(artist)
        artists_with_gender_data.append(artist)
    elif artist["Gender"] != "female" and artist["Gender"] != "male":
        non_binary_artists = []
        non_binary_artists.append(artist)
    else:
        other_artists = []

print(len(female_artists))
print(len(male_artists))
print(len(non_binary_artists))
print(len(artists_with_gender_data))
#print(len(other_artists))
# Out:
# 1
# 1
# 1
# 12494
